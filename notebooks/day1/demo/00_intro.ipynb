# %% [markdown]
# # Welcome
#
# **Databricks Certified Data Engineer Associate — 3-Day Training (6h/day)**
#
# Welcome to the training! This opening module covers the agenda, learning objectives, and environment setup.
#
# | | |
# |---|---|
# | **Organizer** | Altcom |
# | **Format** | 3 days, hands-on (demos + labs + quizzes), 6h of content/day |
# | **Certification** | Databricks Certified Data Engineer Associate |
# | **Exam guide** | May 4, 2026 — 7 domains |
# | **Coverage** | 100% exam domains |
#
# ## RetailHub Scenario
#
# Throughout the training we build a **RetailHub** data platform — an e-commerce company processing orders, customers, and products.
#
# You will:
# - Ingest raw CSV/JSON data into the Bronze layer
# - Transform and cleanse data into Silver
# - Build aggregated Gold tables for analytics
# - Automate the pipeline with Lakeflow and Jobs
# - Secure it with Unity Catalog governance

# %% [markdown]
# ## 3-Day Agenda
#
# **6 hours of content per day** (360 min net; breaks come on top — the times below assume 15' + 30' lunch + 15'). Every module: concept → short demo → lab.
#
# ### Day 1 — Platform, Ingestion, Lakeflow Connect, Delta Lake
#
# | Time | Block | Type |
# |---|---|---|
# | 09:00–09:20 | Welcome, RetailHub scenario, agenda, **environment smoke test** | intro + hands-on |
# | 09:20–10:05 | Platform: UC hierarchy, compute types & cost models, serverless, Spark basics (lazy evaluation, Spark UI) | theory + demo |
# | 10:05–10:30 | **Lab 01** — serverless notebook, UC, Volumes | guided lab |
# | 10:30–10:45 | *Break* | |
# | 10:45–11:30 | Ingestion: readers & schemas, `read_files()`, CTAS, JDBC, ingestion decision framework | demo |
# | 11:30–12:15 | **Lab 02** — ingestion (CSV/JSON/Parquet, schemas, CTAS) | independent lab |
# | 12:15–12:45 | *Lunch* | |
# | 12:45–13:15 | **Lakeflow Connect** — managed SQL Server connector, CDC round-trip | trainer demo |
# | 13:15–14:15 | Delta Lake: DML & MERGE, history, time travel, RESTORE, VACUUM, managed vs external | demo |
# | 14:15–14:30 | *Break* | |
# | 14:30–15:10 | **Lab 03** — Delta DML & time travel | independent lab |
# | 15:10–15:35 | **Day-1 quiz** (Q1–20) + review | quiz |
# | 15:35–16:00 | Buffer — lab catch-up, environment issues, Q&A | buffer |
#
# ### Day 2 — Optimization, Incremental Ingestion, Medallion, Lakeflow Pipelines
#
# | Time | Block | Type |
# |---|---|---|
# | 09:00–09:10 | Recap of Day 1 | review |
# | 09:10–09:20 | Transformations — **self-study briefing**: what to work through in `05a` + `lab_06` (exam objectives 3.1–3.5) and how to check yourself | briefing |
# | 09:20–10:05 | Optimization: OPTIMIZE/VACUUM, Liquid Clustering, `CLUSTER BY AUTO`, predictive optimization, deletion vectors, skew & AQE | demo |
# | 10:05–10:40 | **Lab 04** — optimization benchmark | independent lab |
# | 10:40–10:55 | *Break* | |
# | 10:55–11:45 | Incremental ingestion: COPY INTO idempotency, Auto Loader (directory listing vs file events), schema evolution | demo |
# | 11:45–12:30 | **Lab 05** — COPY INTO + Auto Loader | independent lab |
# | 12:30–13:00 | *Lunch* | |
# | 13:00–13:30 | Medallion architecture (bronze → silver → gold), gold objects | theory + demo |
# | 13:30–14:15 | **Lakeflow Spark Declarative Pipelines**: ST vs MV, `STREAM()`, expectations, AUTO CDC — DEMO 1 condensed | demo |
# | 14:15–14:30 | *Break* | |
# | 14:30–15:15 | **Lab 07** — build & run the RetailHub pipeline (Tasks 1–5) | guided + independent |
# | 15:15–15:40 | **Day-2 quiz** (Q21–40, incl. transformation questions) + review | quiz |
# | 15:40–16:00 | Buffer — lab catch-up, Q&A | buffer |
#
# ### Day 3 — Jobs, CI/CD, Troubleshooting, Governance, Exam
#
# | Time | Block | Type |
# |---|---|---|
# | 09:00–09:10 | Recap of Day 2 | review |
# | 09:10–09:55 | Lakeflow Jobs: task types, DAG, triggers, retries, if/else, `for_each`, parameters & task values, run history | demo |
# | 09:55–10:50 | **Lab 08** — multi-task job (Section 1 + Tasks A–E) | guided lab |
# | 10:50–11:05 | *Break* | |
# | 11:05–11:35 | CI/CD: Git folders flow, Declarative Automation Bundles, variables & targets, CLI | demo |
# | 11:35–12:10 | **Lab 09** — deploy RetailHub as a bundle (incl. Git folder step) | guided lab |
# | 12:10–12:40 | *Lunch* | |
# | 12:40–13:15 | **Troubleshooting exercise** — broken job (Tasks 1–5) | debugging lab |
# | 13:15–13:55 | Governance: managed vs external (`SET MANAGED`), GRANT/REVOKE, masks & row filters, ABAC | demo |
# | 13:55–14:10 | *Break* | |
# | 14:10–14:50 | **Lab 10** — governance (Tasks 1–9) | independent lab |
# | 14:50–15:35 | **Exam prep** — domains, traps, strategy + **Day-3 quiz** (Q41–68) with review | wrap-up + quiz |
# | 15:35–16:00 | Buffer / final Q&A, feedback, teardown reminder | buffer |
#
# > Hands-on share per day is ~50% — labs and quizzes are the core of the training, not an add-on.
# >
# > **Self-study:** the transformations module `05a` + `lab_06` (exam domain 3, 22%), sections marked **⏭️ Self-study** in the notebooks and **stretch** tasks in the labs.

# %% [markdown]
# ## Exam Domains — May 4, 2026
#
# | # | Domain | Weight | Training Day |
# |---|--------|--------|--------------|
# | 1 | Databricks Intelligence Platform | **6%** | Day 1 |
# | 2 | Data Ingestion and Loading | **21%** | Day 1 |
# | 3 | Data Transformation and Modeling | **22%** | Day 2 + **self-study** (`05a`, `lab_06`) |
# | 4 | Working with Lakeflow Jobs | **16%** | Day 3 |
# | 5 | Implementing CI/CD | **10%** | Day 3 |
# | 6 | Troubleshooting, Monitoring, and Optimization | **10%** | Day 2–3 |
# | 7 | Data Governance and Security | **15%** | Day 3 |
#
# > The current exam **strongly emphasizes Lakeflow Connect, Lakeflow Spark Declarative Pipelines and Lakeflow Jobs**.
#
# > **Exam format:** 45 scored questions (plus unscored), 90 minutes, $200. **Passing score: not published** — it is set statistically; aim for **≥80% on practice quizzes**.
#
# > **Exam guide:** https://www.databricks.com/learn/certification/data-engineer-associate

# %% [markdown]
# ## Setup
#
# Run the cell below — it calls the shared `00_setup` notebook, which validates your environment (catalog, schemas, dataset Volume) and exports the variables `CATALOG`, `BRONZE_SCHEMA`, `SILVER_SCHEMA`, `GOLD_SCHEMA`, and `DATASET_PATH` used by every module and lab.

# %%
# %run ../../setup/00_setup

# %%
# Quick environment check — uses the variables exported by 00_setup
print(f"Catalog: {CATALOG}")
print(f"Schemas: {BRONZE_SCHEMA}, {SILVER_SCHEMA}, {GOLD_SCHEMA}")
print(f"Dataset: {DATASET_PATH}")

spark.sql(f"USE CATALOG {CATALOG}")
print(f"\nCatalog '{CATALOG}' is ready!")

# %% [markdown]
# ## Training Materials
#
# | Resource | Location | When |
# |----------|----------|------|
# | Demo notebooks | `notebooks/dayX/demo/` | Follow along with trainer |
# | Lab notebooks | `notebooks/dayX/lab/` | Hands-on exercises |
# | Setup | `notebooks/setup/` | Run before Day 1 |
# | Medallion pipeline components | `materials/medallion/` | Day 2 medallion & Lakeflow lab |
# | Orchestration helpers | `materials/orchestration/` | Day 3 Job lab |
# | Participant PDFs (EN / PL) | `docs/ENG/`, `docs/PL/` | Cheatsheet, quiz, exam objectives map, next steps, practical guides |
#
# > **Tip:** Your catalog, schemas and dataset Volume are provisioned by the trainer (`00_pre_config`); `00_setup` only validates them — run it (via the Setup cell above) before the first session.

# %% [markdown]
# ## Ground Rules
#
# 1. **Ask questions anytime** — interruptions welcome
# 2. **Labs are self-paced** — finish early? Try bonus challenges
# 3. **Mistakes are welcome** — that's how we learn Delta recovery
# 4. **Collaborate** — discuss approaches with neighbors
#
# **[ README](../../../README.md)** | [01 — Platform & Workspace →](01_platform_and_workspace.ipynb)
